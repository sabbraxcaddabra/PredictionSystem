# %%
import pandas as pd
import numpy as np

import scipy.stats as st

import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)

import os

sns.set()

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import ipywidgets as widgets
from ipywidgets import interact, HBox, VBox, Label

# %%
df = pd.read_csv('../Данные/out_w_date_an_orig.csv')

# %%
df.head()
# Out:
#    abiturient_id  status    add_time  id  \
# 0      202100008       1  2021-04-09  11
# 1      202100009       1  2021-04-22   3
# 2      202100622       1  2021-06-24  33
# 3      202100622       1  2021-06-24  18
# 4      202100622       1  2021-06-24  32
#
#                                                 name  true  \
# 0                                     Машиностроение     1
# 1                              Программная инженерия     1
# 2   Проектирование авиационных и ракетных двигателей     0
# 3                  Ракетные комплексы и космонавтика     0
# 4  Проектирование, производство и эксплуатация ра...     0
#
#                                           ex     point  eduform_id  fintype_id
# 0             Математика,Физика,Русский язык  74,55,72           2           2
# 1  Математика,Информатика и ИКТ,Русский язык  98,88,59           2           2
# 2             Математика,Физика,Русский язык  72,51,76           1           1
# 3             Математика,Физика,Русский язык  72,51,76           1           1
# 4             Математика,Физика,Русский язык  72,51,76           1           1

# %%
df['point_mean'] = df['point'].apply(lambda x: sum(map(int, x.split(',')))/len(x.split(',')))
df = df[df['point_mean'] > 0]

# %%
df.head()
# Out:
#    abiturient_id  status    add_time  id  \
# 0      202100008       1  2021-04-09  11
# 1      202100009       1  2021-04-22   3
# 2      202100622       1  2021-06-24  33
# 3      202100622       1  2021-06-24  18
# 4      202100622       1  2021-06-24  32
#
#                                                 name  true  \
# 0                                     Машиностроение     1
# 1                              Программная инженерия     1
# 2   Проектирование авиационных и ракетных двигателей     0
# 3                  Ракетные комплексы и космонавтика     0
# 4  Проектирование, производство и эксплуатация ра...     0
#
#                                           ex     point  eduform_id  \
# 0             Математика,Физика,Русский язык  74,55,72           2
# 1  Математика,Информатика и ИКТ,Русский язык  98,88,59           2
# 2             Математика,Физика,Русский язык  72,51,76           1
# 3             Математика,Физика,Русский язык  72,51,76           1
# 4             Математика,Физика,Русский язык  72,51,76           1
#
#    fintype_id  point_mean
# 0           2   67.000000
# 1           2   81.666667
# 2           1   66.333333
# 3           1   66.333333
# 4           1   66.333333

# %%
df['ex'].unique()
# Out:
# array(['Математика,Физика,Русский язык',
#        'Математика,Информатика и ИКТ,Русский язык',
#        'Математика,Обществознание,Русский язык',
#        'Математика,Биология,Русский язык',
#        'Иностранный язык,Обществознание,Русский язык',
#        'Иностранный язык,Математика,Русский язык',
#        'Русский язык,Обществознание,Иностранный язык'], dtype=object)

# %%
pd.value_counts(df[df['name']=='Экономика']['status'])
# Out:
# 1    102
# 0     26
# Name: status, dtype: int64

# %%
gdf_mean = df.groupby(['name']).agg({'point_mean': ['mean', 'count'],
                                     'true': [lambda x: np.bincount(x)[1]],
                                     'status': [lambda x: np.bincount(x)[1]]
                                    }).transpose()

# %%
gdf_mean.head()
# Out:
# name                 Баллистика и гидроаэродинамика  Боеприпасы и взрыватели  \
# point_mean mean                           64.057143                62.903509
#            count                         245.000000               342.000000
# true       <lambda>                       24.000000                99.000000
# status     <lambda>                      152.000000               218.000000
#
# name                 Двигатели летательных аппаратов  \
# point_mean mean                            67.333333
#            count                          275.000000
# true       <lambda>                        29.000000
# status     <lambda>                       186.000000
#
# name                 Интегрированные системы летательных аппаратов  \
# point_mean mean                                           73.53493
#            count                                         167.00000
# true       <lambda>                                       33.00000
# status     <lambda>                                       89.00000
#
# name                 Информатика и вычислительная техника  \
# point_mean mean                                 72.331393
#            count                               859.000000
# true       <lambda>                             99.000000
# status     <lambda>                            461.000000
#
# name                 Информационные системы и технологии  \
# point_mean mean                                72.075055
#            count                              906.000000
# true       <lambda>                           109.000000
# status     <lambda>                           495.000000
#
# name                 Конструкторско-технологическое обеспечение машиностроительных производств  \
# point_mean mean                                              63.353047
#            count                                            186.000000
# true       <lambda>                                          33.000000
# status     <lambda>                                         112.000000
#
# name                 Лазерная техника и лазерные технологии  Машиностроение  \
# point_mean mean                                   68.419048       64.991546
#            count                                 210.000000      276.000000
# true       <lambda>                               40.000000       60.000000
# status     <lambda>                              160.000000      191.000000
#
# name                 Менеджмент  ...  \
# point_mean mean       63.084541  ...
#            count     138.000000  ...
# true       <lambda>   52.000000  ...
# status     <lambda>  114.000000  ...
#
# name                 Стрелково-пушечное, артиллерийское и ракетное оружие  \
# point_mean mean                                              64.140741
#            count                                            315.000000
# true       <lambda>                                          36.000000
# status     <lambda>                                         197.000000
#
# name                 Теплоэнергетика и теплотехника  \
# point_mean mean                               67.76
#            count                             200.00
# true       <lambda>                           18.00
# status     <lambda>                          130.00
#
# name                 Технологические машины и оборудование  \
# point_mean mean                                  61.979622
#            count                                229.000000
# true       <lambda>                              20.000000
# status     <lambda>                             134.000000
#
# name                 Техносферная безопасность  \
# point_mean mean                      64.527778
#            count                     60.000000
# true       <lambda>                   6.000000
# status     <lambda>                  40.000000
#
# name                 Управление в технических системах  Управление персоналом  \
# point_mean mean                              67.821839              63.115385
#            count                            174.000000             104.000000
# true       <lambda>                          18.000000              25.000000
# status     <lambda>                         115.000000              90.000000
#
# name                 Фотоника и оптоинформатика  \
# point_mean mean                       74.591522
#            count                     173.000000
# true       <lambda>                   21.000000
# status     <lambda>                   90.000000
#
# name                 Фундаментальная и прикладная лингвистика   Экономика  \
# point_mean mean                                     68.654762   61.132813
#            count                                    56.000000  128.000000
# true       <lambda>                                 37.000000   51.000000
# status     <lambda>                                 46.000000  102.000000
#
# name                 Энергетическое машиностроение
# point_mean mean                          66.015504
#            count                        172.000000
# true       <lambda>                      19.000000
# status     <lambda>                     107.000000
#
# [4 rows x 37 columns]

# %%
def spec_summary(x):
    '''
    Общая инфа по специальностям
    '''
    bal = gdf_mean[x][0] # Средний балл
    count = int(gdf_mean[x][1]) # Число заявлений
    count_true = int(gdf_mean[x][2]) # Число поступивших
    count_status = int(gdf_mean[x][3]) # Число поданных согласий
    res_str = f'''
    Cредний бал: {bal:5.1f}
    Число заявлений: {count}
    Число поступивших: {count_true}
    Число поданных согласий: {count_status}
    Отношение числа поступивших к общему числу заявлений: {count_true/count:5.3f}
    Отношение числа подавших согласие к общему числу заявлений: {count_status/count:5.3f}
    '''
    print(res_str)

dropdown_spec = widgets.Dropdown(
    options=gdf_mean.columns,
)

interact(spec_summary, x=dropdown_spec);
# Out:
# interactive(children=(Dropdown(description='x', options=('Баллистика и гидроаэродинамика', 'Боеприпасы и взрыв…

# %%
def spec_hist(x, y):
    
    spec_df = df[df['name'] == x]
    
    color_dict = ['true', 'status']
    
        
    fst_group = spec_df[spec_df[color_dict[y]] == 0]
    sec_group = spec_df[spec_df[color_dict[y]] == 1]

    # Проверка стат гипотез

    # Проверка на нормальность

    p_vals = np.array([
        st.normaltest(fst_group['point_mean'])[1],
        st.normaltest(sec_group['point_mean'])[1]
    ])
    print('Проверка на нормальность')
    print(f'P-value для группы 0: {p_vals[0]:5.4f}')
    print(f'P-value для группы 1: {p_vals[1]:5.4f}')

    if np.all(p_vals > 0.05):
        print('Обе выборки нормальны. t-тест Стьюдента')
        print(st.ttest_ind(fst_group['point_mean'], sec_group['point_mean']))
    else:
        print('Выборки ненормальны. U-критерий Мана-Уитни')
        print(st.mannwhitneyu(fst_group['point_mean'], sec_group['point_mean']))


    fig = px.histogram(data_frame=spec_df, x='point_mean', color=color_dict[y], marginal='box')
    fig.show()
    
dropdown_spec = widgets.Dropdown(
    options=df['name'].unique(),
)

dropdown_obj_pack = widgets.Dropdown(
    options = df['ex'].unique()
)

dropdown_status_or_true = widgets.Dropdown(
    options=list(zip(['Поступившие/Не поступившие', 'Есть согласие/Нет согласия'], (0, 1))),
)

interact(spec_hist, x=dropdown_spec, y=dropdown_status_or_true);
# Out:
# interactive(children=(Dropdown(description='x', options=('Машиностроение', 'Программная инженерия', 'Проектиро…

# %%
def obj_pack_hist(obj_pack, y):
    
    obj_pack_df = df[df['ex'] == obj_pack]
    
    color_dict = ['true', 'status']
    
    fig = px.histogram(data_frame=obj_pack_df, x='point_mean', color=color_dict[y], marginal='box')
    fig.show()
    
interact(obj_pack_hist, obj_pack=dropdown_obj_pack, y=dropdown_status_or_true);
# Out:
# interactive(children=(Dropdown(description='obj_pack', options=('Математика,Физика,Русский язык', 'Математика,…

# %%
def spec_bal_line(x, y):
    spec_df = df[df['name'] == x]
    
    bins = np.arange(30, 105, 5)
    ylabel = [
        'Отношение числа поступивших к числу непоступивших',
        'Отношение числа с согласием к числу без согласия'
    ]
    enrolled_or_agreed = ['true', 'status'][y]
    print(pd.value_counts(spec_df[enrolled_or_agreed]))
    
    hist_0 = np.histogram(spec_df[spec_df[enrolled_or_agreed] == 0]['point_mean'], bins=bins)[0]
    hist_1 = np.histogram(spec_df[spec_df[enrolled_or_agreed] == 1]['point_mean'], bins=bins)[0]
    
    hist_res = np.zeros(hist_0.shape[0])
    
    an_bins = np.arange(32.5, 100, 5)
    
    for i in range(hist_res.shape[0]):
        if hist_0[i] != 0:
            hist_res[i] = hist_1[i]/hist_0[i]
    
    fig = px.line(x=an_bins, y=hist_res, markers=True)
    fig.update_layout(
        xaxis = dict(
            title='Баллы',
            tickmode = 'linear',
            tick0 = 30,
            dtick = 5
        ),
        yaxis = dict(title=ylabel[y])
    )
    fig.show()

hbpx_spec = HBox([
    Label('Специальность/Направление подготовки'),
    dropdown_spec
])

hbpx_status_or_true = HBox([
    Label('Поступившие/Не поступившие или Есть согласие/Нет согласия'),
    dropdown_status_or_true
])
    
vbox = widgets.VBox([hbpx_spec, hbpx_status_or_true])

out = widgets.interactive_output(spec_bal_line, {'x': dropdown_spec, 'y': dropdown_status_or_true})
display(vbox, out);
# Out:
# VBox(children=(HBox(children=(Label(value='Специальность/Направление подготовки'), Dropdown(description='x', o…
# Output()
